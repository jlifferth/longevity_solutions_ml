# %%
import pandas as pd

# this notebook copied from https://github.com/nachi-hebbar/Time-Series-Forecasting-MachineLearning
# video tutorial at https://www.youtube.com/watch?v=BJ6kyj-st9k

# %%
df = pd.read_csv('Alcohol_Sales.csv', index_col='DATE', parse_dates=True)
df.index.freq = 'MS'

# %%
df.tail()
# Out:
#             S4248SM144NCEN
# DATE
# 2018-09-01           12396
# 2018-10-01           13914
# 2018-11-01           14174
# 2018-12-01           15504
# 2019-01-01           10718

# %%
df.columns = ['Sales']
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='DATE'>
